# %%
# !pip install apyori

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from apyori import apriori

df1 = pd.read_csv('./MSK_WHS1_FY19_P3.csv')
df2 = pd.read_csv('./MSK_WHS1_FY19_P5.csv')
df3 = pd.read_csv('./MSK_WHS1_FY19_P8.csv')

df = pd.concat([df1, df2, df3], ignore_index=True)

# %%
df.head(2)
# Out:
#    MBWHSE           MBDATE    MBMBRN  MBDEPT  MBITEM  MBREG_NUM  MBTRN_NUM  \
# 0       1   10/5/2018 0:00  33335737      17  972150          6        435
# 1       1  11/18/2018 0:00  12430582      65   39054          6        244
#
#    MBTIME  MBSELL  MBDSUN  MBDSEL  FISCAL_YEAR  FISCAL_PERIOD IMCAT1  \
# 0    1943   14.49       1   14.49           19              2      C
# 1    1533    4.79       1    4.79           19              3      1
#
#                     IMDES1                     IMDES2 IMCAT2 IMCAT3  \
# 0  NAKED VTY SMTH 12/10 OZ  DOM 90/SL 50    T26H7P182      A      A
# 1     PERUVIAN SWEET ONION                        NaN      O      1
#
#                CDDESC M2EXCFLG
# 0  PASTEURIZED JUICES        N
# 1               SWEET        E

# %%
g = df.groupby(['MBMBRN', 'MBTRN_NUM', 'MBREG_NUM']).IMDES1.unique()
g

# %%
association_rules = apriori([i for i in g], min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = [*association_rules]

# %%
association_results.sort(key=lambda x: x[2][0][3], reverse=True)
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: CABERNET SAUVIGNON -> RED BLEND RED MERITAGE
# Support: 0.004980690800158805
# Confidence: 0.323269130661114
# Lift: 11.715064704119659
# ...
# Rule: BLACKBERRIES -> RASPBERRIES
# Support: 0.005048864506763233
# Confidence: 0.2561025223759154
# Lift: 11.14723220234341
# ...
# Rule: BLACKBERRIES -> RASPBERRIES
# Support: 0.009139286903028917
# Confidence: 0.4635882831570382
# Lift: 8.821868517467072
# ...
# Rule: SNACKS AND BARS -> FRUIT SNACKS SINGLES
# Support: 0.004776169680345521
# Confidence: 0.24979026845637584
# Lift: 7.7032464399069065
# ...
# Rule: BATH TISSUE -> ROLLED PAPER TOWELS
# Support: 0.004720026627847756
# Confidence: 0.4806043282972642
# Lift: 6.9070910677880635
# ...
# Rule: BATH TISSUE -> ROLLED PAPER TOWELS
# Support: 0.0050528747247987876
# Confidence: 0.4452296819787986
# Lift: 6.3986980109088325
# ...
# Rule: CUCUMBERS -> PEPPERS
# Support: 0.006472491909385114
# Confidence: 0.20917573872472786
# Lift: 6.38598062385092
# ...
# Rule: RASPBERRIES -> BLUEBERRIES
# Support: 0.005578213287456439
# ...
